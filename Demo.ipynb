# %%
from xvla import xvla
model = xvla(action_mode = 'ee6d', pretrained = "/mnt/petrelfs/zhengjinliang/HeteroDiffusionPolicy/AbsEEFFlowV8/exp/pretrain/pretraining_32_finalist/ckpt-200K-64/model.safetensors")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/transformers/configuration_utils.py:688, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     686 else:
#     687     # Load config dict
# --> 688     config_dict = cls._dict_from_json_file(resolved_config_file)
#     690 config_dict["_commit_hash"] = commit_hash
#
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/transformers/configuration_utils.py:797, in PretrainedConfig._dict_from_json_file(cls, json_file)
#     796     text = reader.read()
# --> 797 return json.loads(text)
#
# File ~/miniconda3/envs/UniAct/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
# ...

# %%
from transformers import AutoModelForCausalLM
vlm = AutoModelForCausalLM.from_pretrained(
            "microsoft/Florence-2-large",
            torch_dtype="auto",
            trust_remote_code=True
        )
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/transformers/configuration_utils.py:688, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     686 else:
#     687     # Load config dict
# --> 688     config_dict = cls._dict_from_json_file(resolved_config_file)
#     690 config_dict["_commit_hash"] = commit_hash
#
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/transformers/configuration_utils.py:797, in PretrainedConfig._dict_from_json_file(cls, json_file)
#     796     text = reader.read()
# --> 797 return json.loads(text)
#
# File ~/miniconda3/envs/UniAct/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
# ...

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="microsoft/Florence-2-large")
# Out:
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/miniconda3/envs/UniAct/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
data = iter(create_dataloader(
        batch_size = 16,
        metas_path = "/mnt/petrelfs/zhengjinliang/HeteroDiffusionPolicy/AbsEEFFlowV8/meta_files/finetuning/3-view-dual/flod_cloth_hq.json",
        num_actions= 30,
        training = True
    ))
# Out:
# == dataset AIR-AGILEX-HQ with 1166 trajs

# %%
d = next(data)

# %%
d['action'][0]
# Out:
# tensor([[ 2.3207e-01, -8.0258e-02,  4.6552e-01, -6.0774e-01,  3.7749e-01,
#           2.2680e-01,  9.2566e-01, -7.6093e-01, -2.5603e-02,  1.0000e+00,
#           1.7076e-01,  9.4062e-02,  4.6733e-01, -6.5039e-01, -2.6670e-01,
#          -1.8539e-01,  9.6375e-01, -7.3645e-01, -7.0878e-03,  1.0000e+00],
#         [ 2.2952e-01, -7.9281e-02,  4.7754e-01, -5.7835e-01,  3.7429e-01,
#           2.1261e-01,  9.2698e-01, -7.8744e-01, -2.4652e-02,  1.0000e+00,
#           1.7049e-01,  9.3047e-02,  4.8178e-01, -6.1643e-01, -2.6729e-01,
#          -1.7234e-01,  9.6361e-01, -7.6812e-01, -1.7352e-03,  1.0000e+00],
#         [ 2.2648e-01, -7.7778e-02,  4.9047e-01, -5.4379e-01,  3.6902e-01,
#           1.9810e-01,  9.2920e-01, -8.1550e-01, -2.0350e-02,  1.0000e+00,
#           1.7122e-01,  9.2811e-02,  4.9642e-01, -5.8175e-01, -2.6754e-01,
#          -1.5798e-01,  9.6354e-01, -7.9788e-01,  4.2945e-03,  1.0000e+00],
#         [ 2.2284e-01, -7.5231e-02,  5.0459e-01, -5.0303e-01,  3.5515e-01,
# ...
